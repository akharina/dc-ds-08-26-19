# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
salary = [80, 45, 67, 88, 99]
schools = ['MIT', 'Stanford', 'UW', 'Harvard', 'UGW']

bars = plt.bar(schools, salary)
plt.title('Early Career Pay for Some Colleges')

bars[1].set_color()

plt.show()

# %%
import pandas as pd

# %%
pd.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a71f5d3fd03c> in <module>
# ----> 1 pd.hist()
#
# AttributeError: module 'pandas' has no attribute 'hist'
